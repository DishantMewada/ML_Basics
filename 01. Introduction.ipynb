# %% [markdown]
# <img src="https://i.imgur.com/mqTCqBR.png" width=1000 height=500 />

# %% [markdown]
# # Data 01: Melbourne Home Prices

# %% [markdown]
# ## Step 01: Exploring The Data

# %%
# import
import pandas as pd
# save filepath to variable for easier access
melbourne_file_path = './data/melbourne-housing-snapshot/melb_data.csv'
# read the data and store data in DataFrame titled melbourne_data
melbourne_home_data = pd.read_csv(melbourne_file_path)

# %%
# print a summary of the data in Melbourne data
melbourne_home_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
# print first 5 rows of the data
melbourne_home_data.head() # doesn't display all columns by default
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
# display all columns
pd.options.display.max_columns = None
# display all rows
# pd.options.display.max_rows = None

# %%
# print first 10 rows of the data
melbourne_home_data.head(n=10)
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford    40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford         55a Park St      4    h  1600000.0     VB  Nelson
# 5  Abbotsford      129 Charles St      2    h   941000.0      S  Jellis
# 6  Abbotsford        124 Yarra St      3    h  1876000.0      S  Nelson
# 7  Abbotsford       98 Charles St      2    h  1636000.0      S  Nelson
# 8  Abbotsford  6/241 Nicholson St      1    u   300000.0      S  Biggin
# 9  Abbotsford       10 Valiant St      2    h  1097000.0      S  Biggin
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# ...

# %% [markdown]
# ## Step 02: Selecting Data for Modeling

# %%
melbourne_home_data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
# columns with missing values
melbourne_home_data.columns[melbourne_home_data.isnull().any()]
# Out:
# Index(['Car', 'BuildingArea', 'YearBuilt', 'CouncilArea'], dtype='object')

# %%
# columns without missing values
melbourne_home_data.columns[melbourne_home_data.notnull().all()]
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Landsize',
#        'Lattitude', 'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
# Visualize null entries first
import seaborn as sns
sns.heatmap(melbourne_home_data.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
# columns with only numeric values - includes NaN
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

print(melbourne_home_data.select_dtypes(include=numerics))
print(melbourne_home_data.select_dtypes(include=numerics).columns)
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0          2  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3          3   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13575      4  1245000.0      16.7    3150.0       4.0       2.0  2.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13577      3  1170000.0       6.8    3016.0       3.0       2.0  4.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# ...

# %%
# columns with numeric and not null values
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
df = melbourne_home_data.select_dtypes(include=numerics) 
df = df.columns[df.notnull().all()]
print(df)
# Out:
# Index(['Rooms', 'Price', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Landsize', 'Lattitude', 'Longtitude', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# ## Drop/fill Missing Values - if needed

# %%
melbourne_home_data = melbourne_home_data.dropna(axis=0) 
# not always a good idea
# drops any row with NaN let it be string or any other type

# %%
# melbourne_home_data = melbourne_home_data.fillna(0) 
## not always a good idea, fills NaN with the value in the bracket

# %%
melbourne_home_data.describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  6196.000000  6.196000e+03  6196.000000  6196.000000  6196.000000
# mean      2.931407  1.068828e+06     9.751097  3101.947708     2.902034
# std       0.971079  6.751564e+05     5.612065    86.421604     0.970055
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.200000e+05     5.900000  3044.000000     2.000000
# 50%       3.000000  8.800000e+05     9.000000  3081.000000     3.000000
# 75%       4.000000  1.325000e+06    12.400000  3147.000000     3.000000
# max       8.000000  9.000000e+06    47.400000  3977.000000     9.000000
#
#           Bathroom          Car      Landsize  BuildingArea    YearBuilt  \
# count  6196.000000  6196.000000   6196.000000   6196.000000  6196.000000
# mean      1.576340     1.573596    471.006940    141.568645  1964.081988
# std       0.711362     0.929947    897.449881     90.834824    38.105673
# ...

# %% [markdown]
# ## Step 03: Selecting The Prediction Target

# %% [markdown]
# Target -> based on the question/requirement

# %%
y = melbourne_home_data.Price

# %%
y
# Out:
# 1        1035000.0
# 2        1465000.0
# 4        1600000.0
# 6        1876000.0
# 7        1636000.0
#            ...
# 12205     601000.0
# 12206    1050000.0
# 12207     385000.0
# 12209     560000.0
# 12212    2450000.0
# Name: Price, Length: 6196, dtype: float64

# %%
y.shape
# Out:
# (6196,)

# %%
print(type(y))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## OR

# %%
melbourne_target = ['Price']
y = melbourne_home_data[melbourne_target]

# %%
y
# Out:
#            Price
# 1      1035000.0
# 2      1465000.0
# 4      1600000.0
# 6      1876000.0
# 7      1636000.0
# ...          ...
# 12205   601000.0
# 12206  1050000.0
# 12207   385000.0
# 12209   560000.0
# 12212  2450000.0
#
# [6196 rows x 1 columns]

# %%
y.shape
# Out:
# (6196, 1)

# %%
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Step 04: Choosing "Features"

# %%
# melbourne_features = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']
# melbourne_features = ['Rooms', 'Price', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car','Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude','Propertycount']
df = df.tolist() # convert index to list
df.remove('Price') # remove the target from features 
melbourne_features = df

# %%
X = melbourne_home_data[melbourne_features]

# %%
X.head()
# Out:
#    Rooms  Distance  Postcode  Bedroom2  Bathroom  Landsize  Lattitude  \
# 1      2       2.5    3067.0       2.0       1.0     156.0   -37.8079
# 2      3       2.5    3067.0       3.0       2.0     134.0   -37.8093
# 4      4       2.5    3067.0       3.0       1.0     120.0   -37.8072
# 6      3       2.5    3067.0       4.0       2.0     245.0   -37.8024
# 7      2       2.5    3067.0       2.0       1.0     256.0   -37.8060
#
#    Longtitude  Propertycount
# 1    144.9934         4019.0
# 2    144.9944         4019.0
# 4    144.9941         4019.0
# 6    144.9993         4019.0
# 7    144.9954         4019.0

# %%
X.describe()
# Out:
#              Rooms     Distance     Postcode     Bedroom2     Bathroom  \
# count  6196.000000  6196.000000  6196.000000  6196.000000  6196.000000
# mean      2.931407     9.751097  3101.947708     2.902034     1.576340
# std       0.971079     5.612065    86.421604     0.970055     0.711362
# min       1.000000     0.000000  3000.000000     0.000000     1.000000
# 25%       2.000000     5.900000  3044.000000     2.000000     1.000000
# 50%       3.000000     9.000000  3081.000000     3.000000     1.000000
# 75%       4.000000    12.400000  3147.000000     3.000000     2.000000
# max       8.000000    47.400000  3977.000000     9.000000     8.000000
#
#            Landsize    Lattitude   Longtitude  Propertycount
# count   6196.000000  6196.000000  6196.000000    6196.000000
# mean     471.006940   -37.807904   144.990201    7435.489509
# std      897.449881     0.075850     0.099165    4337.698917
# min        0.000000   -38.164920   144.542370     389.000000
# ...

# %% [markdown]
# ## Step 05: Building the Model + Evaluate the model

# %% [markdown]
# ### Model : Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
# Step 1: Define model
melbourne_model = DecisionTreeRegressor(random_state=1) # random_state provides same result in each run : good practice
# Step 2: Fit model - Capture patterns from provided data. This is the heart of modeling.
melbourne_model.fit(X, y) 
# Step 3: Predict
print("Making predictions for the following 5 houses:")
print(X.head())
print("The predictions are")
pred = melbourne_model.predict(X.head()) # X.head() makes it in-sample prediction
print(pred)
# Step 4: Evaluate - Determine how accurate the model's predictions are.
'''    Confusion matrix
    Accuracy
    Precision
    Recall
    Specificity
    F1 score
    Precision-Recall or PR curve
    ROC (Receiver Operating Characteristics) curve
'''
from sklearn.metrics import mean_absolute_error,accuracy_score,precision_score,recall_score,f1_score
    
# MAE - takes abs(errors) ie |real-predicted| and takes average of all
mae = mean_absolute_error(y.head(), pred)  
print('MAE: %f' % mae)
# Out:
# Making predictions for the following 5 houses:
#    Rooms  Distance  Postcode  Bedroom2  Bathroom  Landsize  Lattitude  \
# 1      2       2.5    3067.0       2.0       1.0     156.0   -37.8079
# 2      3       2.5    3067.0       3.0       2.0     134.0   -37.8093
# 4      4       2.5    3067.0       3.0       1.0     120.0   -37.8072
# 6      3       2.5    3067.0       4.0       2.0     245.0   -37.8024
# 7      2       2.5    3067.0       2.0       1.0     256.0   -37.8060
#
#    Longtitude  Propertycount
# 1    144.9934         4019.0
# 2    144.9944         4019.0
# 4    144.9941         4019.0
# 6    144.9993         4019.0
# 7    144.9954         4019.0
# The predictions are
# [1035000. 1465000. 1600000. 1876000. 1636000.]
# MAE: 0.000000

# %%
## Common practice is to split the data after assigning features and target
from sklearn import model_selection
from sklearn.metrics import accuracy_score, mean_absolute_error

# Step 0: Split the model into train and test
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.20, random_state=1) 
# Step 1: Define model
melbourne_model = DecisionTreeRegressor(random_state=1)
# Step 2: Fit model
melbourne_model.fit(X_train, y_train)
# Step 3: Predict
pred = melbourne_model.predict(X_test)
# Step 4: Evaluate
mae = mean_absolute_error(y_test, pred)
print('MAE: %f' % mae)
# Out:
# MAE: 254390.783871

# %% [markdown]
# ### Model : Random Forest
# The random forest uses many trees, and it makes a prediction by averaging the predictions of each component tree. It generally has much better predictive accuracy than a single decision tree and it works well with default parameters.

# %% [markdown]
# The decision trees implemented in scikit-learn uses only numerical features and these features are interpreted always as continuous numeric variables. To include strings as feautures, people usually use one-hot encode categorical variables.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Step 0 : Split Split the model into train and test
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.20, random_state=1) 
# Step 1: Define model
melbourne_model = RandomForestRegressor(random_state=1)
# Step 2: Fit model
melbourne_model.fit(X_train, y_train.values.ravel())
# Step 3: Predict
pred = melbourne_model.predict(X_test)
# Step 4: Evaluate
mae = mean_absolute_error(y_test, pred)
print('MAE with Random Forest: %f' % mae)
# Out:
# MAE with Random Forest: 181183.298319

# %% [markdown]
# Random forest usually performs better than decision tree and usually no tuning needed

# %% [markdown]
# ## Step 06: Tuning your model
# ## Overfitting and Underfitting
# <img src="https://i.imgur.com/2q85n9s.png" width=500 height=500 />
#
# ### Overfitting: Good performance on the training data, poor generliazation to other data.
# ### Underfitting: Poor performance on the training data and poor generalization to other data
#
# Overfitting refers to a model that models the training data too well.
#
# Overfitting happens when a model learns the detail and noise in the training data to the extent that it negatively impacts the performance of the model on new data. This means that the noise or random fluctuations in the training data is picked up and learned as concepts by the model. The problem is that these concepts do not apply to new data and negatively impact the models ability to generalize.
#
# Underfitting refers to a model that can neither model the training data nor generalize to new data.
#
# An underfit machine learning model is not a suitable model and will be obvious as it will have poor performance on the training data.
#
# Ideally, you want to select a model at the sweet spot between underfitting and overfitting. But is very difficult to do in practice.

# %% [markdown]
# There are two important techniques that you can use when evaluating machine learning algorithms to limit overfitting:
#
# Use a resampling technique to estimate model accuracy: The most popular resampling technique is k-fold cross validation. It allows you to train and test your model k-times on different subsets of training data and build up an estimate of the performance of a machine learning model on unseen data.
#
# Hold back a validation dataset: A validation dataset is simply a subset of your training data that you hold back from your machine learning algorithms until the very end of your project. After you have selected and tuned your machine learning algorithms on your training dataset you can evaluate the learned models on the validation dataset to get a final objective idea of how the models might perform on unseen data. Using cross validation is a gold standard in applied machine learning for estimating model accuracy on unseen data. If you have the data, using a validation dataset is also an excellent practice.

# %% [markdown]
# ### Model : Decision Tree

# %%
# max_leaf_nodes argument provides a very sensible way to control overfitting vs underfitting in Decision Tree
def get_mae(max_leaf_nodes, X_train, y_train, X_test, y_test):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=1)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    return(mae)

# %%
# compare MAE with differing values of max_leaf_nodes
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, X_train, y_train, X_test, y_test)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  358166
# Max leaf nodes: 50  		 Mean Absolute Error:  256853
# Max leaf nodes: 500  		 Mean Absolute Error:  240642
# Max leaf nodes: 5000  		 Mean Absolute Error:  255504

# %%
# model having least error is the best model
import numpy as np
my_list = np.arange(5, 5000, 10).tolist()

mae_dict = {}
for max_leaf_nodes in my_list:
    my_mae = get_mae(max_leaf_nodes, X_train, y_train, X_test, y_test)
    mae_dict[max_leaf_nodes] = my_mae
    
best_key = min(mae_dict, key=mae_dict.get)
print('best_max_leaf_node: %d with min_MAE: %f' %(best_key, min(mae_dict.values())))
# Out:
# best_max_leaf_node: 175 with min_MAE: 228286.706523

# %%
# same thing with dictionary comprehension
candidate_max_leaf_nodes = np.arange(5, 5000, 10).tolist()

scores = {leaf_size: get_mae(leaf_size, X_train, y_train, X_test, y_test) for leaf_size in candidate_max_leaf_nodes}
best_tree_size = min(scores, key=scores.get)
best_tree_size
# Out:
# 175

# %% [markdown]
# <img src="https://i.imgur.com/R3ywQsR.png" width=500 height=500 />
#
# A deep tree with lots of leaves will overfit because each prediction is coming from historical data from only the few houses at its leaf(last node). But a shallow tree with few leaves will perform poorly because it fails to capture as many distinctions in the raw data.

# %% [markdown]
# # Data 02: Iowa Home data

# %% [markdown]
# ## Step 01: Exploring The Data

# %%
# import
import pandas as pd
# save filepath to variable for easier access
iowa_file_path = './data/iowa_home_data/train.csv'
# read the data and store data in DataFrame titled melbourne_data
iowa_home_data = pd.read_csv(iowa_file_path)

# %%
# print a summary of the data in Melbourne data
iowa_home_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
# display all columns
pd.options.display.max_columns = None
# print first 10 rows of the data
iowa_home_data.head(n=10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %% [markdown]
# ## Step 02: Selecting Data for Modeling

# %%
iowa_home_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# columns with missing values
iowa_home_data.columns[iowa_home_data.isnull().any()]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
# columns without missing values
iowa_home_data.columns[iowa_home_data.notnull().all()]
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageCars', 'GarageArea', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
import seaborn as sns
# Checking various null entries in the dataset, with the help of heatmap
sns.heatmap(iowa_home_data.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
# columns with only numeric values - includes NaN
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

print(iowa_home_data.select_dtypes(include=numerics))
print(iowa_home_data.select_dtypes(include=numerics).columns)
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
# columns with numeric and not null values
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
df = iowa_home_data.select_dtypes(include=numerics) 
df = df.columns[df.notnull().all()]
print(df)
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ## Drop/fill Missing Values - removes all rows from df in this case

# %%
# Extract three relevant columns from home data into a new dataframe
df_test = iowa_home_data[['YrSold', 'YearRemodAdd', 'YearBuilt']]
# Create a histogram from each column sharing the same x-axis
df_test.plot.hist(figsize=(12, 10), subplots=True, bins=50); # plot requires matplotlib

# %% [markdown]
# ### how old is the newest home?

# %%
iowa_home_data[['YrSold','YearBuilt']].describe()
# Out:
#             YrSold    YearBuilt
# count  1460.000000  1460.000000
# mean   2007.815753  1971.267808
# std       1.328095    30.202904
# min    2006.000000  1872.000000
# 25%    2007.000000  1954.000000
# 50%    2008.000000  1973.000000
# 75%    2009.000000  2000.000000
# max    2010.000000  2010.000000

# %%
from datetime import date
current_year = date.today().year;
newest_home_age = (current_year - iowa_home_data.loc[:,'YearBuilt'].max()) #df.loc[rows:columns]
newest_home_age
# Out:
# 11

# %% [markdown]
# ### What is the average lot size (rounded to nearest integer)?

# %%
iowa_home_data[['LotArea']].describe()
# Out:
#              LotArea
# count    1460.000000
# mean    10516.828082
# std      9981.264932
# min      1300.000000
# 25%      7553.500000
# 50%      9478.500000
# 75%     11601.500000
# max    215245.000000

# %%
avg_lot_size = iowa_home_data.loc[:,'LotArea'].mean()
avg_lot_size = round(avg_lot_size, 0)
avg_lot_size
# Out:
# 10517.0

# %% [markdown]
# ## Step 03: Selecting The Prediction Target

# %%
y = iowa_home_data.SalePrice
y.shape
# Out:
# (1460,)

# %% [markdown]
# ## Step 04: Choosing "Features"

# %%
# iowa_feature_columns = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
df = df.tolist() # convert index to list
df.remove('SalePrice') # remove the target from features
df.remove('Id')
iowa_feature_columns = df
X = iowa_home_data[iowa_feature_columns]
print(X.head(n=10))
X.shape
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0          60     8450            7            5       2003          2003
# 1          20     9600            6            8       1976          1976
# 2          60    11250            7            5       2001          2002
# 3          70     9550            7            5       1915          1970
# 4          60    14260            8            5       2000          2000
# 5          50    14115            5            5       1993          1995
# 6          20    10084            8            5       2004          2005
# 7          60    10382            7            6       1973          1973
# 8          50     6120            7            5       1931          1950
# 9         190     7420            5            6       1939          1950
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# 0         706           0        150          856       856       854
# ...

# %%
X.head()
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0          60     8450            7            5       2003          2003
# 1          20     9600            6            8       1976          1976
# 2          60    11250            7            5       2001          2002
# 3          70     9550            7            5       1915          1970
# 4          60    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# 0         706           0        150          856       856       854
# 1         978           0        284         1262      1262         0
# 2         486           0        434          920       920       866
# 3         216           0        540          756       961       756
# 4         655           0        490         1145      1145      1053
#
#    LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# ...

# %%
X.describe()
# Out:
#         MSSubClass        LotArea  OverallQual  OverallCond    YearBuilt  \
# count  1460.000000    1460.000000  1460.000000  1460.000000  1460.000000
# mean     56.897260   10516.828082     6.099315     5.575342  1971.267808
# std      42.300571    9981.264932     1.382997     1.112799    30.202904
# min      20.000000    1300.000000     1.000000     1.000000  1872.000000
# 25%      20.000000    7553.500000     5.000000     5.000000  1954.000000
# 50%      50.000000    9478.500000     6.000000     5.000000  1973.000000
# 75%      70.000000   11601.500000     7.000000     6.000000  2000.000000
# max     190.000000  215245.000000    10.000000     9.000000  2010.000000
#
#        YearRemodAdd   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF  \
# count   1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    1984.865753   443.639726    46.549315   567.240411  1057.429452
# std       20.645407   456.098091   161.319273   441.866955   438.705324
# ...

# %% [markdown]
# ## Step 05: Building the Model + Evaluate the model

# %% [markdown]
# ### Model: Decision Tree

# %%
# Step 0: Split train-test
from sklearn.model_selection import train_test_split as split
X_train, X_test, y_train, y_test = split(X, y, random_state=0) 

# Step 1: Define model
from sklearn.tree import DecisionTreeRegressor
iowa_home_model = DecisionTreeRegressor()

# Step 2: Fit model 
iowa_home_model.fit(X_train, y_train)

# Step 3: Predict
y_pred = iowa_home_model.predict(X_test)

# Step 4: Evaluate
from sklearn.metrics import mean_absolute_error
print('DecisionTreeRegressor MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# DecisionTreeRegressor MAE: 25162.084931506848

# %% [markdown]
# Step 06: Tuning the model - Decision Tree

# %%
import numpy as np
my_list = np.arange(5, 5000, 10).tolist()

mae_dict = {}
for max_leaf_nodes in my_list:
    my_mae = get_mae(max_leaf_nodes, X_train, y_train, X_test, y_test)
    mae_dict[max_leaf_nodes] = my_mae
    
best_key = min(mae_dict, key=mae_dict.get)
print('best_max_leaf_node: %d with min_MAE: %f' %(best_key, min(mae_dict.values())))
# Out:
# best_max_leaf_node: 85 with min_MAE: 23810.285085

# %% [markdown]
# ### Model: Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Step 0 : Split Split the model into train and test
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.20, random_state=0) 
# Step 1: Define model
iowa_home_model = RandomForestRegressor(random_state=1)
# Step 2: Fit model
iowa_home_model.fit(X_train, y_train)
# Step 3: Predict
pred = iowa_home_model.predict(X_test)
# Step 4: Evaluate
mae = mean_absolute_error(y_test, pred)
print('MAE with RandomForest: %f' % mae)
# Out:
# MAE with RandomForest: 17591.619007

# %% [markdown]
# # Data 03: Housing Price Competition

# %% [markdown]
# ## Step 01: Exploring The Data

# %% [markdown]
# ### We have two files - train.csv & test.csv
#
# If you choose features from train.csv and
# fit the model on train.csv and then
# finally fit on test.csv with same features,
# your features might be irrelevant.
#
# The same goes vice versa.
#
# Solution:
#
# Choose features from test.csv first,
#
# Choose features from train.csv,
#
# then features(test.csv) ∩ features(train.csv)

# %%
import pandas as pd

house_price_train_file_path = './data/Housing Price Competition/train.csv'

house_price_train_data = pd.read_csv(house_price_train_file_path) 

house_price_test_file_path = './data/Housing Price Competition/test.csv'

house_price_test_data = pd.read_csv(house_price_test_file_path)

# %% [markdown]
# ### test data

# %%
house_price_test_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704
# std       1.113740    30.390071     21.130467   177.625900   455.268042
# ...

# %%
# print first 10 rows of the data
house_price_test_data.head(n=10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5  1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6  1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7  1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8  1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9  1470          20       RL         70.0     8400   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# ...

# %% [markdown]
# ### train data

# %%
house_price_train_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
# print first 10 rows of the data
house_price_train_data.head(n=10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %% [markdown]
# ## Step 02: Selecting Data for Modeling

# %% [markdown]
# ### test data

# %%
house_price_test_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# columns with missing values
house_price_test_data.columns[house_price_test_data.isnull().any()]
# Out:
# Index(['MSZoning', 'LotFrontage', 'Alley', 'Utilities', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
#        'BsmtHalfBath', 'KitchenQual', 'Functional', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea',
#        'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType'],
#       dtype='object')

# %%
# columns without missing values
house_price_test_data.columns[house_price_test_data.notnull().all()]
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'Street', 'LotShape', 'LandContour',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'ExterQual', 'ExterCond',
#        'Foundation', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleCondition'],
#       dtype='object')

# %%
# Visualize null entries first
import seaborn as sns
sns.heatmap(house_price_test_data.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
# columns with only numeric values - includes NaN
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

print(house_price_test_data.select_dtypes(include=numerics))
print(house_price_test_data.select_dtypes(include=numerics).columns)
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     1461          20         80.0    11622            5            6
# 1     1462          20         81.0    14267            6            6
# 2     1463          60         74.0    13830            5            5
# 3     1464          60         78.0     9978            6            6
# 4     1465         120         43.0     5005            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1454  2915         160         21.0     1936            4            7
# 1455  2916         160         21.0     1894            4            5
# 1456  2917          20        160.0    20000            5            7
# 1457  2918          85         62.0    10441            5            5
# 1458  2919          60         74.0     9627            7            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
# columns with numeric and not null values
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
df_test = house_price_test_data.select_dtypes(include=numerics) 
df_test = df_test.columns[df_test.notnull().all()]
print(df_test)
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'TotRmsAbvGrd', 'Fireplaces', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %% [markdown]
# ### train data

# %%
house_price_train_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# columns with missing values
house_price_train_data.columns[house_price_train_data.isnull().any()]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
# columns without missing values
house_price_train_data.columns[house_price_train_data.notnull().all()]
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageCars', 'GarageArea', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
# Visualize null entries first
import seaborn as sns
sns.heatmap(house_price_train_data.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
# columns with only numeric values - includes NaN
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

print(house_price_train_data.select_dtypes(include=numerics))
print(house_price_train_data.select_dtypes(include=numerics).columns)
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
# columns with numeric and not null values
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
df_train = house_price_train_data.select_dtypes(include=numerics) 
df_train = df_train.columns[df_train.notnull().all()]
print(df_train)
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ## Drop/fill Missing Values
# very limited dataset, not a good idea to drop missing values

# %% [markdown]
# ## Step 03: Selecting The Prediction Target

# %%
y = house_price_train_data.SalePrice

# %%
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
y.shape
# Out:
# (1460,)

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
# house_price_features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
# house_price_features = ['MSSubClass','LotArea','OverallQual','OverallCond','YearBuilt','YearRemodAdd','YrSold','LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
df_train = df_train.tolist()
# no need to remove the target from features, will be removed via intersection

df_test = df_test.tolist()

# intersection of these two lists as features
df = [value for value in df_test if value in df_train]

house_price_features = df

# %%
X = house_price_train_data[house_price_features]

# %%
X.head(n=10)
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
# 5   6          50    14115            5            5       1993          1995
# 6   7          20    10084            8            5       2004          2005
# 7   8          60    10382            7            6       1973          1973
# 8   9          50     6120            7            5       1931          1950
# 9  10         190     7420            5            6       1939          1950
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  FullBath  HalfBath  \
# ...

# %%
X.describe()
# Out:
#                 Id   MSSubClass        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    56.897260   10516.828082     6.099315     5.575342
# std     421.610009    42.300571    9981.264932     1.382997     1.112799
# min       1.000000    20.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    20.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    50.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    70.000000   11601.500000     7.000000     6.000000
# max    1460.000000   190.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd     1stFlrSF     2ndFlrSF  LowQualFinSF  \
# count  1460.000000   1460.000000  1460.000000  1460.000000   1460.000000
# mean   1971.267808   1984.865753  1162.626712   346.992466      5.844521
# std      30.202904     20.645407   386.587738   436.528436     48.623081
# ...

# %% [markdown]
# ## Step 05: Building the Model + Evaluate the model

# %% [markdown]
# ### Model : Random Forest

# %% [markdown]
# ### Using train.csv to fit and evaluate the dataset

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split as split

# Step 0 : Split Split the model into train and test
X_train, X_test, y_train, y_test = split(X, y, test_size=0.20, random_state=1) 
# Step 1: Define model
house_price_model = RandomForestRegressor(random_state=1)
# Step 2: Fit model
house_price_model.fit(X_train, y_train)
# Step 3: Predict
pred = house_price_model.predict(X_test)
# Step 4: Evaluate
mae = mean_absolute_error(y_test, pred)
print('MAE with Random Forest: %f' % mae)
# Out:
# MAE with Random Forest: 18400.241130

# %% [markdown]
# ### Use now the entire dataset (train.csv) for fitting and use test.csv

# %%
house_price_full_model = RandomForestRegressor(random_state=1)
house_price_full_model.fit(X,y)
# Out:
# RandomForestRegressor(random_state=1)

# %%
X_test = house_price_test_data[house_price_features]

# %%
X_test
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0     1461          20    11622            5            6       1961
# 1     1462          20    14267            6            6       1958
# 2     1463          60    13830            5            5       1997
# 3     1464          60     9978            6            6       1998
# 4     1465         120     5005            8            5       1992
# ...    ...         ...      ...          ...          ...        ...
# 1454  2915         160     1936            4            7       1970
# 1455  2916         160     1894            4            5       1970
# 1456  2917          20    20000            5            7       1960
# 1457  2918          85    10441            5            5       1992
# 1458  2919          60     9627            7            5       1993
#
#       YearRemodAdd  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  FullBath  \
# ...

# %%
test_preds = house_price_full_model.predict(X_test)

# %% [markdown]
# ## Exporting the result to csv file

# %%
output = pd.DataFrame({'Id': house_price_test_data.Id,
                       'SalePrice': test_preds})
output.to_csv('house_price_output.csv', index=False)
